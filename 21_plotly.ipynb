# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv(r"E:\work\suds_sig6\omron_samples\csv_files\CA43F0B62495_interval_60.csv", index_col=0)
print(df.head())
# Out:
#                         timestamp  data_mode  sequence_number  temparature  \
# datetime
# 2024-05-04 08:49:23  1.714748e+09          1              205        24.51
# 2024-05-04 08:50:26  1.714748e+09          1               11        24.58
# 2024-05-04 08:51:27  1.714748e+09          1               73        24.57
# 2024-05-04 08:52:27  1.714748e+09          1              133        24.67
# 2024-05-04 08:53:29  1.714748e+09          1              195        24.76
#
#                      relative_humidity  ambient_light  barometric_pressure  \
# datetime
# 2024-05-04 08:49:23              52.98            470             1018.733
# 2024-05-04 08:50:26              52.92            470             1018.741
# 2024-05-04 08:51:27              53.13            470             1018.739
# 2024-05-04 08:52:27              52.88            470             1018.770
# 2024-05-04 08:53:29              52.75            467             1018.773
#
#                      sound_noise  eTVOC  eCO2
# datetime
# 2024-05-04 08:49:23        53.14     33   620
# 2024-05-04 08:50:26        52.88     34   627
# 2024-05-04 08:51:27        52.64     36   637
# 2024-05-04 08:52:27        52.86     34   627
# 2024-05-04 08:53:29        53.16     36   641

# %%
fig = px.line(df, y="temparature", title='sensor data')
fig.show()
